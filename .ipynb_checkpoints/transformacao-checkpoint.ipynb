# %%
import pandas as pd
import pandera as pa

# %%
valores_ausentes = ['**','###!','####','****','*****','NULL']
df = pd.read_csv("ocorrencia_2010_2020.csv", parse_dates=['ocorrencia_dia'], dayfirst=True, na_values=valores_ausentes)
df.head(10)
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
# 5              39807               39807                INCIDENTE
# 6              40215               40215                INCIDENTE
# 7              39707               39707          INCIDENTE GRAVE
# 8              39156               39156          INCIDENTE GRAVE
# 9              39711               39711          INCIDENTE GRAVE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                  NaN     03/01/2010
# 1               BELÉM            PA                 SBBE     03/01/2010
# ...

# %%
schema = pa.DataFrameSchema(
    columns = {
        "codigo_ocorrencia":pa.Column(pa.Int),
        "codigo_ocorrencia2":pa.Column(pa.Int),
        "ocorrencia_classificacao":pa.Column(pa.String),
        "ocorrencia_cidade":pa.Column(pa.String),
        "ocorrencia_uf":pa.Column(pa.String),
        "ocorrencia_aerodromo":pa.Column(pa.String, nullable=True),
        "ocorrencia_dia":pa.Column(pa.String, nullable=True),
        "ocorrencia_hora":pa.Column(pa.String, nullable=True),
    }
)

# %%
schema.validate(df)
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                 40349               40349                INCIDENTE
# 2                 40351               40351                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 4                 40324               40324                INCIDENTE
# ...                 ...                 ...                      ...
# 5747              79804               79804                INCIDENTE
# 5748              79757               79757          INCIDENTE GRAVE
# 5749              79802               79802                INCIDENTE
# 5750              79756               79756          INCIDENTE GRAVE
# 5751              79844               79844                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
df.dtypes
# Out:
# codigo_ocorrencia            int64
# codigo_ocorrencia2           int64
# ocorrencia_classificacao    object
# ocorrencia_cidade           object
# ocorrencia_uf               object
# ocorrencia_aerodromo        object
# ocorrencia_dia              object
# ocorrencia_hora             object
# total_recomendacoes         object
# dtype: object

# %%
df.loc[1]
# Out:
# codigo_ocorrencia                40349
# codigo_ocorrencia2               40349
# ocorrencia_classificacao     INCIDENTE
# ocorrencia_cidade                BELÉM
# ocorrencia_uf                       PA
# ocorrencia_aerodromo              SBBE
# ocorrencia_dia              03/01/2010
# ocorrencia_hora               11:05:00
# total_recomendacoes                  1
# Name: 1, dtype: object

# %%
df.iloc[-1]
# Out:
# codigo_ocorrencia               79844
# codigo_ocorrencia2              79844
# ocorrencia_classificacao    INCIDENTE
# ocorrencia_cidade                 -43
# ocorrencia_uf                      37
# ocorrencia_aerodromo               RJ
# ocorrencia_dia                 BRASIL
# ocorrencia_hora                  SBJR
# total_recomendacoes               NÃO
# Name: 5751, dtype: object

# %%
df.tail()
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 5747              79804               79804                INCIDENTE
# 5748              79757               79757          INCIDENTE GRAVE
# 5749              79802               79802                INCIDENTE
# 5750              79756               79756          INCIDENTE GRAVE
# 5751              79844               79844                INCIDENTE
#
#       ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 5747           CAMPINAS            SP                 SBKP     29/12/2020
# 5748  LAGOA DA CONFUSÃO            TO                  NaN     30/12/2020
# 5749     RIO DE JANEIRO            RJ                 SBGL     30/12/2020
# 5750          VICENTINA            MS                  NaN     31/12/2020
# 5751                -43            37                   RJ         BRASIL
#
#      ocorrencia_hora total_recomendacoes
# 5747        19:00:00                   0
# ...

# %%
df.iloc[10:15]
# Out:
#     codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 10              39789               39789                INCIDENTE
# 11              40069               40069                 ACIDENTE
# 12              40414               40414                INCIDENTE
# 13              39507               39507                 ACIDENTE
# 14              40107               40107                 ACIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 10    SÃO PEDRO DO SUL            RS                  NaN     10/01/2010
# 11           SÃO PAULO            SP                 SBMT     10/01/2010
# 12            BRASÍLIA            DF                 SBBR     10/01/2010
# 13  PRIMAVERA DO LESTE            MT                  NaN     11/01/2010
# 14              GURUPÁ            PA                 SNGU     12/01/2010
#
#    ocorrencia_hora total_recomendacoes
# 10        21:30:00                   1
# 11        14:50:00                   8
# ...

# %%
df.loc[10:15]
# Out:
#     codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 10              39789               39789                INCIDENTE
# 11              40069               40069                 ACIDENTE
# 12              40414               40414                INCIDENTE
# 13              39507               39507                 ACIDENTE
# 14              40107               40107                 ACIDENTE
# 15              39315               39315                 ACIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 10    SÃO PEDRO DO SUL            RS                  NaN     10/01/2010
# 11           SÃO PAULO            SP                 SBMT     10/01/2010
# 12            BRASÍLIA            DF                 SBBR     10/01/2010
# 13  PRIMAVERA DO LESTE            MT                  NaN     11/01/2010
# 14              GURUPÁ            PA                 SNGU     12/01/2010
# ...

# %%
df.loc[:,'ocorrencia_uf']
# Out:
# 0       RJ
# 1       PA
# 2       RJ
# 3       MT
# 4       RS
#         ..
# 5747    SP
# 5748    TO
# 5749    RJ
# 5750    MS
# 5751    37
# Name: ocorrencia_uf, Length: 5752, dtype: object

# %%
df['ocorrencia_uf']
# Out:
# 0       RJ
# 1       PA
# 2       RJ
# 3       MT
# 4       RS
#         ..
# 5747    SP
# 5748    TO
# 5749    RJ
# 5750    MS
# 5751    37
# Name: ocorrencia_uf, Length: 5752, dtype: object

# %%
df.isna().sum()
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  0
# ocorrencia_aerodromo        2343
# ocorrencia_dia                 1
# ocorrencia_hora                6
# total_recomendacoes            1
# dtype: int64

# %%
df.isnull().sum()
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  0
# ocorrencia_aerodromo        2343
# ocorrencia_dia                 1
# ocorrencia_hora                6
# total_recomendacoes            1
# dtype: int64

# %%
filtro = df.ocorrencia_uf.isnull()
df.loc[filtro]
# Out:
# Empty DataFrame
# Columns: [codigo_ocorrencia, codigo_ocorrencia2, ocorrencia_classificacao, ocorrencia_cidade, ocorrencia_uf, ocorrencia_aerodromo, ocorrencia_dia, ocorrencia_hora, total_recomendacoes]
# Index: []

# %%
filtro = df.ocorrencia_aerodromo.isnull()
df.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 5                 39807               39807                INCIDENTE
# 7                 39707               39707          INCIDENTE GRAVE
# 9                 39711               39711          INCIDENTE GRAVE
# ...                 ...                 ...                      ...
# 5741              79754               79754          INCIDENTE GRAVE
# 5744              79753               79753          INCIDENTE GRAVE
# 5745              79755               79755                 ACIDENTE
# 5748              79757               79757          INCIDENTE GRAVE
# 5750              79756               79756          INCIDENTE GRAVE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
filtro = df.ocorrencia_hora.isnull()
df.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 2920              52697               52697          INCIDENTE GRAVE
# 4100              78823               78823                INCIDENTE
# 4491              78035               78035          INCIDENTE GRAVE
# 5472              79385               79385          INCIDENTE GRAVE
# 5514              79445               79445                 ACIDENTE
# 5735              79799               79799                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 2920               -42     890274583                   RJ         BRASIL
# 4100           CORUMBÁ            MS                  NaN     09/07/2017
# 4491                16       6372222                   GO         BRASIL
# 5472               -51          6530                   PA         BRASIL
# 5514               -62       1408920                   RO         BRASIL
# ...

# %%
df.count()
# Out:
# codigo_ocorrencia           5752
# codigo_ocorrencia2          5752
# ocorrencia_classificacao    5752
# ocorrencia_cidade           5752
# ocorrencia_uf               5752
# ocorrencia_aerodromo        3409
# ocorrencia_dia              5751
# ocorrencia_hora             5746
# total_recomendacoes         5751
# dtype: int64

# %%
#ocorrências cuja classificação == INCIDENTE GRAVE 
filtro = df.ocorrencia_classificacao == 'INCIDENTE GRAVE'
df.loc[filtro, ['ocorrencia_cidade', 'total_recomendacoes']]
# Out:
#       ocorrencia_cidade total_recomendacoes
# 7              CANUTAMA                   3
# 8              CASCAVEL                   2
# 9         PARÁ DE MINAS                   1
# 29             CURITIBA                   2
# 35               PALMAS                   0
# ...                 ...                 ...
# 5741       NOVA MARINGÁ                   0
# 5744           GOIATUBA                   0
# 5746      MANOEL URBANO                   0
# 5748  LAGOA DA CONFUSÃO                   0
# 5750          VICENTINA                   0
#
# [737 rows x 2 columns]

# %%
#ocorrências cuja classificação == INCIDENTE GRAVE 
filtro = df.ocorrencia_classificacao == 'INCIDENTE GRAVE'
df.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 7                 39707               39707          INCIDENTE GRAVE
# 8                 39156               39156          INCIDENTE GRAVE
# 9                 39711               39711          INCIDENTE GRAVE
# 29                39709               39709          INCIDENTE GRAVE
# 35                39487               39487          INCIDENTE GRAVE
# ...                 ...                 ...                      ...
# 5741              79754               79754          INCIDENTE GRAVE
# 5744              79753               79753          INCIDENTE GRAVE
# 5746              79769               79769          INCIDENTE GRAVE
# 5748              79757               79757          INCIDENTE GRAVE
# 5750              79756               79756          INCIDENTE GRAVE
#
#       ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
#ocorrências cuja classificação == INCIDENTE GRAVE e estado == SP
filtro1 = df.ocorrencia_classificacao == 'INCIDENTE GRAVE'
filtro2 = df.ocorrencia_uf == 'SP'
df.loc[filtro1 & filtro2]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 136               40270               40270          INCIDENTE GRAVE
# 171               40620               40620          INCIDENTE GRAVE
# 219               41411               41411          INCIDENTE GRAVE
# 297               42289               42289          INCIDENTE GRAVE
# 314               42323               42323          INCIDENTE GRAVE
# ...                 ...                 ...                      ...
# 5591              79540               79540          INCIDENTE GRAVE
# 5610              79566               79566          INCIDENTE GRAVE
# 5704              79739               79739          INCIDENTE GRAVE
# 5705              79705               79705          INCIDENTE GRAVE
# 5715              79718               79718          INCIDENTE GRAVE
#
#           ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
#ocorrências cuja classificação == INCIDENTE GRAVE ou o estado == SP
filtro1 = df.ocorrencia_classificacao == 'INCIDENTE GRAVE'
filtro2 = df.ocorrencia_uf == 'SP'
df.loc[filtro1 | filtro2]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 7                 39707               39707          INCIDENTE GRAVE
# 8                 39156               39156          INCIDENTE GRAVE
# 9                 39711               39711          INCIDENTE GRAVE
# 11                40069               40069                 ACIDENTE
# 16                39809               39809                INCIDENTE
# ...                 ...                 ...                      ...
# 5744              79753               79753          INCIDENTE GRAVE
# 5746              79769               79769          INCIDENTE GRAVE
# 5747              79804               79804                INCIDENTE
# 5748              79757               79757          INCIDENTE GRAVE
# 5750              79756               79756          INCIDENTE GRAVE
#
#       ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
#ocorrências cuja (classificação == INCIDENTE GRAVE ou classificação == INCIDENTE) e o estado == SP
filtro1 = df.ocorrencia_classificacao.isin(['INCIDENTE GRAVE', 'INCIDENTE'])
filtro2 = df.ocorrencia_uf == 'SP'
df.loc[filtro1 & filtro2]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 16                39809               39809                INCIDENTE
# 18                39828               39828                INCIDENTE
# 26                39847               39847                INCIDENTE
# 27                39768               39768                INCIDENTE
# 33                39848               39848                INCIDENTE
# ...                 ...                 ...                      ...
# 5704              79739               79739          INCIDENTE GRAVE
# 5705              79705               79705          INCIDENTE GRAVE
# 5715              79718               79718          INCIDENTE GRAVE
# 5742              79800               79800                INCIDENTE
# 5747              79804               79804                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
#ocorrencia cuja cidade começa com a letra c
filtro = df.ocorrencia_cidade.str[0] == 'C'
df.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 6                 40215               40215                INCIDENTE
# 7                 39707               39707          INCIDENTE GRAVE
# 8                 39156               39156          INCIDENTE GRAVE
# 15                39315               39315                 ACIDENTE
# 20                40310               40310                INCIDENTE
# ...                 ...                 ...                      ...
# 5661              79649               79649                INCIDENTE
# 5663              79652               79652                INCIDENTE
# 5680              79683               79683                INCIDENTE
# 5696              79692               79692                 ACIDENTE
# 5747              79804               79804                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
#ocorrencia cuja cidade terminam com a letra a
filtro = df.ocorrencia_cidade.str[-1] == 'A'
df.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 7                 39707               39707          INCIDENTE GRAVE
# 12                40414               40414                INCIDENTE
# 15                39315               39315                 ACIDENTE
# 25                39772               39772                INCIDENTE
# 26                39847               39847                INCIDENTE
# ...                 ...                 ...                      ...
# 5738              79787               79787                INCIDENTE
# 5739              79749               79749                 ACIDENTE
# 5743              79824               79824                 ACIDENTE
# 5744              79753               79753          INCIDENTE GRAVE
# 5750              79756               79756          INCIDENTE GRAVE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
#ocorrencia cuja cidade começa com a caracteres MA
filtro = df.ocorrencia_cidade.str[-2:] == 'MA'
df.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 7                 39707               39707          INCIDENTE GRAVE
# 15                39315               39315                 ACIDENTE
# 408               43062               43062                 ACIDENTE
# 688               44198               44198                 ACIDENTE
# 1035              51785               51785                INCIDENTE
# 1377              45939               45939                 ACIDENTE
# 1401              46180               46180                 ACIDENTE
# 2099              49113               49113          INCIDENTE GRAVE
# 2102              48799               48799                 ACIDENTE
# 2655              51347               51347                INCIDENTE
# 2855              52340               52340                 ACIDENTE
# 2966              52832               52832                 ACIDENTE
# 2997              52979               52979                 ACIDENTE
# ...

# %%
#ocorrencia cuja cidade contém em qualquer parte do conteúdo os caracteres MA
filtro = df.ocorrencia_cidade.str.contains('MA|LA')
df.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 7                 39707               39707          INCIDENTE GRAVE
# 13                39507               39507                 ACIDENTE
# 15                39315               39315                 ACIDENTE
# 28                39321               39321                 ACIDENTE
# 35                39487               39487          INCIDENTE GRAVE
# ...                 ...                 ...                      ...
# 5739              79749               79749                 ACIDENTE
# 5741              79754               79754          INCIDENTE GRAVE
# 5745              79755               79755                 ACIDENTE
# 5746              79769               79769          INCIDENTE GRAVE
# 5748              79757               79757          INCIDENTE GRAVE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %% [raw]
# #ocorrencia do ano 2015 e mês 12 e dia 8
# filtro_ano = df.ocorrencia_dia.dt.year == 2015
# filtro_mes = df.ocorrencia_dia.dt.month == 12
# filtro_dia_inicio = df.ocorrencia_dia.dt.day > 2
# filtro_dia_fim = df.ocorrencia_dia.dt.day < 10
# df.loc[filtro_ano & filtro_mes & filtro_dia_inicio & filtro_dia_fim]

# %%
df['ocorrencia_dia_hora'] = pd.to_datetime(df.ocorrencia_dia.astype(str) + ' ' + df.ocorrencia_hora)

# %%
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                  NaN     03/01/2010
# 1               BELÉM            PA                 SBBE     03/01/2010
# 2      RIO DE JANEIRO            RJ                 SBRJ     03/01/2010
# 3  LUCAS DO RIO VERDE            MT                  NaN     04/01/2010
# 4             PELOTAS            RS                 SBPK     05/01/2010
#
#   ocorrencia_hora total_recomendacoes  ocorrencia_dia_hora
# 0        12:00:00                   1  03/01/2010 12:00:00
# ...
