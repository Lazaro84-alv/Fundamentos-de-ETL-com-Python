# %%
import pandas as pd

# %%
df = pd.read_csv("ocorrencia_2010_2020.csv", parse_dates=['ocorrencia_dia'], dayfirst=True)
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                 ****     03/01/2010
# 1               BELÉM            PA                 SBBE     03/01/2010
# 2      RIO DE JANEIRO            RJ                 SBRJ     03/01/2010
# 3  LUCAS DO RIO VERDE            MT                 ****     04/01/2010
# 4             PELOTAS            RS                 SBPK     05/01/2010
#
#   ocorrencia_hora total_recomendacoes
# 0        12:00:00                   1
# 1        11:05:00                   1
# 2        03:00:00                   1
# 3        17:30:00                   1
# 4        19:25:00                   1

# %%
df.loc[1, 'ocorrencia_cidade']
# Out:
# 'BELÉM'

# %%
df.loc[1:3]
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 1               BELÉM            PA                 SBBE     03/01/2010
# 2      RIO DE JANEIRO            RJ                 SBRJ     03/01/2010
# 3  LUCAS DO RIO VERDE            MT                 ****     04/01/2010
#
#   ocorrencia_hora total_recomendacoes
# 1        11:05:00                   1
# 2        03:00:00                   1
# 3        17:30:00                   1

# %%
df.loc[[10,40]]
# Out:
#     codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 10              39789               39789                INCIDENTE
# 40              39158               39158                INCIDENTE
#
#    ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 10  SÃO PEDRO DO SUL            RS                 ****     10/01/2010
# 40             BELÉM            PA                 ****     28/01/2010
#
#    ocorrencia_hora total_recomendacoes
# 10        21:30:00                   1
# 40        16:00:00                   0

# %%
df.loc[:,'ocorrencia_cidade']
# Out:
# 0           RIO DE JANEIRO
# 1                    BELÉM
# 2           RIO DE JANEIRO
# 3       LUCAS DO RIO VERDE
# 4                  PELOTAS
#                ...
# 5747              CAMPINAS
# 5748     LAGOA DA CONFUSÃO
# 5749        RIO DE JANEIRO
# 5750             VICENTINA
# 5751                   -43
# Name: ocorrencia_cidade, Length: 5752, dtype: object

# %%
df.codigo_ocorrencia.is_unique
# Out:
# True

# %%
df.set_index('codigo_ocorrencia', inplace=True)

# %%
df.head()
# Out:
#                    codigo_ocorrencia2 ocorrencia_classificacao  \
# codigo_ocorrencia
# 40211                           40211                INCIDENTE
# 40349                           40349                INCIDENTE
# 40351                           40351                INCIDENTE
# 39527                           39527                 ACIDENTE
# 40324                           40324                INCIDENTE
#
#                     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo  \
# codigo_ocorrencia
# 40211                  RIO DE JANEIRO            RJ                 ****
# 40349                           BELÉM            PA                 SBBE
# 40351                  RIO DE JANEIRO            RJ                 SBRJ
# 39527              LUCAS DO RIO VERDE            MT                 ****
# 40324                         PELOTAS            RS                 SBPK
#
#                   ocorrencia_dia ocorrencia_hora total_recomendacoes
# codigo_ocorrencia
# 40211                 03/01/2010        12:00:00                   1
# 40349                 03/01/2010        11:05:00                   1
# 40351                 03/01/2010        03:00:00                   1
# 39527                 04/01/2010        17:30:00                   1
# 40324                 05/01/2010        19:25:00                   1

# %%
df.loc[40324]
# Out:
# codigo_ocorrencia2               40324
# ocorrencia_classificacao     INCIDENTE
# ocorrencia_cidade              PELOTAS
# ocorrencia_uf                       RS
# ocorrencia_aerodromo              SBPK
# ocorrencia_dia              05/01/2010
# ocorrencia_hora               19:25:00
# total_recomendacoes                  1
# Name: 40324, dtype: object

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.head()
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao   ocorrencia_cidade  \
# 0               40211                INCIDENTE      RIO DE JANEIRO
# 1               40349                INCIDENTE               BELÉM
# 2               40351                INCIDENTE      RIO DE JANEIRO
# 3               39527                 ACIDENTE  LUCAS DO RIO VERDE
# 4               40324                INCIDENTE             PELOTAS
#
#   ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0            RJ                 ****     03/01/2010        12:00:00
# 1            PA                 SBBE     03/01/2010        11:05:00
# 2            RJ                 SBRJ     03/01/2010        03:00:00
# 3            MT                 ****     04/01/2010        17:30:00
# 4            RS                 SBPK     05/01/2010        19:25:00
#
#   total_recomendacoes
# 0                   1
# 1                   1
# 2                   1
# 3                   1
# 4                   1

# %%
df.loc[0,'ocorrencia_aerodromo'] = ''

# %%
df.head(1)
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_cidade  \
# 0               40211                INCIDENTE    RIO DE JANEIRO
#
#   ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0            RJ                          03/01/2010        12:00:00
#
#   total_recomendacoes
# 0                   1

# %%
df.loc[1] = 20

# %%
df.head(2)
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_cidade  \
# 0               40211                INCIDENTE    RIO DE JANEIRO
# 1                  20                       20                20
#
#   ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0            RJ                          03/01/2010        12:00:00
# 1            20                   20             20              20
#
#   total_recomendacoes
# 0                   1
# 1                  20

# %%
df.loc[:, 'total_recomendacoes'] = 10

# %%
df
# Out:
#       codigo_ocorrencia2 ocorrencia_classificacao   ocorrencia_cidade  \
# 0                  40211                INCIDENTE      RIO DE JANEIRO
# 1                     20                       20                  20
# 2                  40351                INCIDENTE      RIO DE JANEIRO
# 3                  39527                 ACIDENTE  LUCAS DO RIO VERDE
# 4                  40324                INCIDENTE             PELOTAS
# ...                  ...                      ...                 ...
# 5747               79804                INCIDENTE            CAMPINAS
# 5748               79757          INCIDENTE GRAVE   LAGOA DA CONFUSÃO
# 5749               79802                INCIDENTE      RIO DE JANEIRO
# 5750               79756          INCIDENTE GRAVE           VICENTINA
# 5751               79844                INCIDENTE                 -43
#
#      ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0               RJ                          03/01/2010        12:00:00
# 1               20                   20             20              20
# 2               RJ                 SBRJ     03/01/2010        03:00:00
# 3               MT                 ****     04/01/2010        17:30:00
# 4               RS                 SBPK     05/01/2010        19:25:00
# ...            ...                  ...            ...             ...
# 5747            SP                 SBKP     29/12/2020        19:00:00
# 5748            TO                 ****     30/12/2020        18:30:00
# 5749            RJ                 SBGL     30/12/2020        00:54:00
# 5750            MS                 ****     31/12/2020        09:00:00
# 5751            37                   RJ         BRASIL            SBJR
#
#       total_recomendacoes
# 0                      10
# 1                      10
# 2                      10
# 3                      10
# 4                      10
# ...                   ...
# 5747                   10
# 5748                   10
# 5749                   10
# 5750                   10
# 5751                   10
#
# [5752 rows x 8 columns]

# %%
df['ocorrencia_uf_bkp'] = df.ocorrencia_uf

# %%
df
# Out:
#       codigo_ocorrencia2 ocorrencia_classificacao   ocorrencia_cidade  \
# 0                  40211                INCIDENTE      RIO DE JANEIRO
# 1                     20                       20                  20
# 2                  40351                INCIDENTE      RIO DE JANEIRO
# 3                  39527                 ACIDENTE  LUCAS DO RIO VERDE
# 4                  40324                INCIDENTE             PELOTAS
# ...                  ...                      ...                 ...
# 5747               79804                INCIDENTE            CAMPINAS
# 5748               79757          INCIDENTE GRAVE   LAGOA DA CONFUSÃO
# 5749               79802                INCIDENTE      RIO DE JANEIRO
# 5750               79756          INCIDENTE GRAVE           VICENTINA
# 5751               79844                INCIDENTE                 -43
#
#      ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0               RJ                          03/01/2010        12:00:00
# 1               20                   20             20              20
# 2               RJ                 SBRJ     03/01/2010        03:00:00
# 3               MT                 ****     04/01/2010        17:30:00
# 4               RS                 SBPK     05/01/2010        19:25:00
# ...            ...                  ...            ...             ...
# 5747            SP                 SBKP     29/12/2020        19:00:00
# 5748            TO                 ****     30/12/2020        18:30:00
# 5749            RJ                 SBGL     30/12/2020        00:54:00
# 5750            MS                 ****     31/12/2020        09:00:00
# 5751            37                   RJ         BRASIL            SBJR
#
#       total_recomendacoes ocorrencia_uf_bkp
# 0                      10                RJ
# 1                      10                20
# 2                      10                RJ
# 3                      10                MT
# 4                      10                RS
# ...                   ...               ...
# 5747                   10                SP
# 5748                   10                TO
# 5749                   10                RJ
# 5750                   10                MS
# 5751                   10                37
#
# [5752 rows x 9 columns]

# %%
df.loc[df.ocorrencia_uf == 'SP', ['ocorrencia_classificacao']] = 'GRAVE'

# %%
df
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                 40349               40349                INCIDENTE
# 2                 40351               40351                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 4                 40324               40324                INCIDENTE
# ...                 ...                 ...                      ...
# 5747              79804               79804                INCIDENTE
# 5748              79757               79757          INCIDENTE GRAVE
# 5749              79802               79802                INCIDENTE
# 5750              79756               79756          INCIDENTE GRAVE
# 5751              79844               79844                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0         RIO DE JANEIRO            RJ                 ****     03/01/2010
# 1                  BELÉM            PA                 SBBE     03/01/2010
# 2         RIO DE JANEIRO            RJ                 SBRJ     03/01/2010
# 3     LUCAS DO RIO VERDE            MT                 ****     04/01/2010
# 4                PELOTAS            RS                 SBPK     05/01/2010
# ...                  ...           ...                  ...            ...
# 5747            CAMPINAS            SP                 SBKP     29/12/2020
# 5748   LAGOA DA CONFUSÃO            TO                 ****     30/12/2020
# 5749      RIO DE JANEIRO            RJ                 SBGL     30/12/2020
# 5750           VICENTINA            MS                 ****     31/12/2020
# 5751                 -43            37                   RJ         BRASIL
#
#      ocorrencia_hora total_recomendacoes
# 0           12:00:00                   1
# 1           11:05:00                   1
# 2           03:00:00                   1
# 3           17:30:00                   1
# 4           19:25:00                   1
# ...              ...                 ...
# 5747        19:00:00                   0
# 5748        18:30:00                   0
# 5749        00:54:00                   0
# 5750        09:00:00                   0
# 5751            SBJR                 NÃO
#
# [5752 rows x 9 columns]

# %%
df.loc[df.ocorrencia_uf == 'SP']
# Out:
#       codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_cidade  \
# 11                 40069                    GRAVE         SÃO PAULO
# 16                 39809                    GRAVE         SÃO PAULO
# 18                 39828                    GRAVE            SANTOS
# 26                 39847                    GRAVE          SOROCABA
# 27                 39768                    GRAVE          CAMPINAS
# ...                  ...                      ...               ...
# 5704               79739                    GRAVE         SÃO PAULO
# 5705               79705                    GRAVE          SOROCABA
# 5715               79718                    GRAVE         SÃO PAULO
# 5742               79800                    GRAVE         SÃO PAULO
# 5747               79804                    GRAVE          CAMPINAS
#
#      ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 11              SP                 SBMT     10/01/2010        14:50:00
# 16              SP                 ****     15/01/2010        15:00:00
# 18              SP                 ****     15/01/2010        17:45:00
# 26              SP                 ****     20/01/2010        13:10:00
# 27              SP                 ****     21/01/2010        20:45:00
# ...            ...                  ...            ...             ...
# 5704            SP                 SBSP     03/12/2020        14:42:00
# 5705            SP                 SDCO     04/12/2020        15:30:00
# 5715            SP                 SBMT     11/12/2020        13:50:00
# 5742            SP                 SBMT     28/12/2020        10:15:00
# 5747            SP                 SBKP     29/12/2020        19:00:00
#
#       total_recomendacoes ocorrencia_uf_bkp
# 11                     10                SP
# 16                     10                SP
# 18                     10                SP
# 26                     10                SP
# 27                     10                SP
# ...                   ...               ...
# 5704                   10                SP
# 5705                   10                SP
# 5715                   10                SP
# 5742                   10                SP
# 5747                   10                SP
#
# [1371 rows x 9 columns]

# %% [raw]
# Ocorrencia_uf
# **
# ocorrencia_aerodromo
# ###!
# ####
# ****
# *****
# ocorrencia_hora
# NULL

# %%
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                 ****     03/01/2010
# 1               BELÉM            PA                 SBBE     03/01/2010
# 2      RIO DE JANEIRO            RJ                 SBRJ     03/01/2010
# 3  LUCAS DO RIO VERDE            MT                 ****     04/01/2010
# 4             PELOTAS            RS                 SBPK     05/01/2010
#
#   ocorrencia_hora total_recomendacoes
# 0        12:00:00                   1
# 1        11:05:00                   1
# 2        03:00:00                   1
# 3        17:30:00                   1
# 4        19:25:00                   1

# %%
df.loc[df.ocorrencia_aerodromo == '****', ['ocorrencia_aerodromo']] = pd.NA

# %%
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                 <NA>     03/01/2010
# 1               BELÉM            PA                 SBBE     03/01/2010
# 2      RIO DE JANEIRO            RJ                 SBRJ     03/01/2010
# 3  LUCAS DO RIO VERDE            MT                 <NA>     04/01/2010
# 4             PELOTAS            RS                 SBPK     05/01/2010
#
#   ocorrencia_hora total_recomendacoes
# 0        12:00:00                   1
# 1        11:05:00                   1
# 2        03:00:00                   1
# 3        17:30:00                   1
# 4        19:25:00                   1

# %%
df.replace(['**','###!','####','****','*****','NULL'], pd.NA, inplace=True)
# Out:
# C:\Users\gabri\anaconda3\lib\site-packages\pandas\core\missing.py:49: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask = arr == x
# C:\Users\gabri\anaconda3\lib\site-packages\pandas\core\missing.py:60: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= arr == x

# %%
df.replace(['**','###!','####','****','*****','NULL'], pd.NA, inplace=True)

# %%
df.isna().sum()
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  0
# ocorrencia_aerodromo        2176
# ocorrencia_dia                 1
# ocorrencia_hora                6
# total_recomendacoes            1
# dtype: int64

# %%
df.isnull().sum()
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  0
# ocorrencia_aerodromo        2176
# ocorrencia_dia                 1
# ocorrencia_hora                6
# total_recomendacoes            1
# dtype: int64

# %%
df.fillna(10, inplace=True)

# %%
df.isnull().sum()
# Out:
# codigo_ocorrencia           0
# codigo_ocorrencia2          0
# ocorrencia_classificacao    0
# ocorrencia_cidade           0
# ocorrencia_uf               0
# ocorrencia_aerodromo        0
# ocorrencia_dia              0
# ocorrencia_hora             0
# total_recomendacoes         0
# dtype: int64

# %%
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                   10     03/01/2010
# 1               BELÉM            PA                 SBBE     03/01/2010
# 2      RIO DE JANEIRO            RJ                 SBRJ     03/01/2010
# 3  LUCAS DO RIO VERDE            MT                   10     04/01/2010
# 4             PELOTAS            RS                 SBPK     05/01/2010
#
#   ocorrencia_hora total_recomendacoes
# 0        12:00:00                   1
# 1        11:05:00                   1
# 2        03:00:00                   1
# 3        17:30:00                   1
# 4        19:25:00                   1

# %%
df.replace([10], pd.NA, inplace=True)

# %%
df.isnull().sum()
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  0
# ocorrencia_aerodromo        2176
# ocorrencia_dia                 1
# ocorrencia_hora                6
# total_recomendacoes            1
# dtype: int64

# %%
df.fillna(value={'total_recomendacoes':10}, inplace=True)

# %%
df.isnull().sum()
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  0
# ocorrencia_aerodromo        2176
# ocorrencia_dia                 1
# ocorrencia_hora                6
# total_recomendacoes            0
# dtype: int64

# %%
df['total_recomendacoes_bkp'] = df.total_recomendacoes

# %%
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                 <NA>     03/01/2010
# 1               BELÉM            PA                 SBBE     03/01/2010
# 2      RIO DE JANEIRO            RJ                 SBRJ     03/01/2010
# 3  LUCAS DO RIO VERDE            MT                 <NA>     04/01/2010
# 4             PELOTAS            RS                 SBPK     05/01/2010
#
#   ocorrencia_hora total_recomendacoes total_recomendacoes_bkp
# 0        12:00:00                   1                       1
# 1        11:05:00                   1                       1
# 2        03:00:00                   1                       1
# 3        17:30:00                   1                       1
# 4        19:25:00                   1                       1

# %%
df.drop(['total_recomendacoes'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                 <NA>     03/01/2010
# 1               BELÉM            PA                 SBBE     03/01/2010
# 2      RIO DE JANEIRO            RJ                 SBRJ     03/01/2010
# 3  LUCAS DO RIO VERDE            MT                 <NA>     04/01/2010
# 4             PELOTAS            RS                 SBPK     05/01/2010
#
#   ocorrencia_hora total_recomendacoes_bkp
# 0        12:00:00                       1
# 1        11:05:00                       1
# 2        03:00:00                       1
# 3        17:30:00                       1
# 4        19:25:00                       1

# %%
df.dropna()
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 1                 40349               40349                INCIDENTE
# 2                 40351               40351                INCIDENTE
# 4                 40324               40324                INCIDENTE
# 6                 40215               40215                INCIDENTE
# 8                 39156               39156          INCIDENTE GRAVE
# ...                 ...                 ...                      ...
# 5743              79824               79824                 ACIDENTE
# 5746              79769               79769          INCIDENTE GRAVE
# 5747              79804               79804                INCIDENTE
# 5749              79802               79802                INCIDENTE
# 5751              79844               79844                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 1                BELÉM            PA                 SBBE     03/01/2010
# 2       RIO DE JANEIRO            RJ                 SBRJ     03/01/2010
# 4              PELOTAS            RS                 SBPK     05/01/2010
# 6                COARI            AM                 SBUY     07/01/2010
# 8             CASCAVEL            PR                 SBCA     10/01/2010
# ...                ...           ...                  ...            ...
# 5743     RIO PARANAÍBA            MG                 SNRP     28/12/2020
# 5746     MANOEL URBANO            AC                 SIMB     29/12/2020
# 5747          CAMPINAS            SP                 SBKP     29/12/2020
# 5749    RIO DE JANEIRO            RJ                 SBGL     30/12/2020
# 5751               -43            37                   RJ         BRASIL
#
#      ocorrencia_hora total_recomendacoes_bkp
# 1           11:05:00                       1
# 2           03:00:00                       1
# 4           19:25:00                       1
# 6           18:40:00                       1
# 8           23:15:00                       2
# ...              ...                     ...
# 5743        17:00:00                       0
# 5746        18:30:00                       0
# 5747        19:00:00                       0
# 5749        00:54:00                       0
# 5751            SBJR                     NÃO
#
# [3569 rows x 9 columns]

# %%
df
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                 40349               40349                INCIDENTE
# 2                 40351               40351                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 4                 40324               40324                INCIDENTE
# ...                 ...                 ...                      ...
# 5747              79804               79804                INCIDENTE
# 5748              79757               79757          INCIDENTE GRAVE
# 5749              79802               79802                INCIDENTE
# 5750              79756               79756          INCIDENTE GRAVE
# 5751              79844               79844                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0         RIO DE JANEIRO            RJ                 <NA>     03/01/2010
# 1                  BELÉM            PA                 SBBE     03/01/2010
# 2         RIO DE JANEIRO            RJ                 SBRJ     03/01/2010
# 3     LUCAS DO RIO VERDE            MT                 <NA>     04/01/2010
# 4                PELOTAS            RS                 SBPK     05/01/2010
# ...                  ...           ...                  ...            ...
# 5747            CAMPINAS            SP                 SBKP     29/12/2020
# 5748   LAGOA DA CONFUSÃO            TO                 <NA>     30/12/2020
# 5749      RIO DE JANEIRO            RJ                 SBGL     30/12/2020
# 5750           VICENTINA            MS                 <NA>     31/12/2020
# 5751                 -43            37                   RJ         BRASIL
#
#      ocorrencia_hora total_recomendacoes_bkp
# 0           12:00:00                       1
# 1           11:05:00                       1
# 2           03:00:00                       1
# 3           17:30:00                       1
# 4           19:25:00                       1
# ...              ...                     ...
# 5747        19:00:00                       0
# 5748        18:30:00                       0
# 5749        00:54:00                       0
# 5750        09:00:00                       0
# 5751            SBJR                     NÃO
#
# [5752 rows x 9 columns]

# %%
df.dropna(subset=['ocorrencia_uf'])
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                 40349               40349                INCIDENTE
# 2                 40351               40351                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 4                 40324               40324                INCIDENTE
# ...                 ...                 ...                      ...
# 5747              79804               79804                INCIDENTE
# 5748              79757               79757          INCIDENTE GRAVE
# 5749              79802               79802                INCIDENTE
# 5750              79756               79756          INCIDENTE GRAVE
# 5751              79844               79844                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0         RIO DE JANEIRO            RJ                 <NA>     03/01/2010
# 1                  BELÉM            PA                 SBBE     03/01/2010
# 2         RIO DE JANEIRO            RJ                 SBRJ     03/01/2010
# 3     LUCAS DO RIO VERDE            MT                 <NA>     04/01/2010
# 4                PELOTAS            RS                 SBPK     05/01/2010
# ...                  ...           ...                  ...            ...
# 5747            CAMPINAS            SP                 SBKP     29/12/2020
# 5748   LAGOA DA CONFUSÃO            TO                 <NA>     30/12/2020
# 5749      RIO DE JANEIRO            RJ                 SBGL     30/12/2020
# 5750           VICENTINA            MS                 <NA>     31/12/2020
# 5751                 -43            37                   RJ         BRASIL
#
#      ocorrencia_hora total_recomendacoes_bkp
# 0           12:00:00                       1
# 1           11:05:00                       1
# 2           03:00:00                       1
# 3           17:30:00                       1
# 4           19:25:00                       1
# ...              ...                     ...
# 5747        19:00:00                       0
# 5748        18:30:00                       0
# 5749        00:54:00                       0
# 5750        09:00:00                       0
# 5751            SBJR                     NÃO
#
# [5752 rows x 9 columns]

# %%
df.drop_duplicates(inplace=True)
